# %%
from empyrial import empyrial, Engine
portfolio = Engine(    
         start_date= "2018-06-09", 
         portfolio= ["BTC", "ETH", "LTC"], 
         weights = [0.2, 0.2, 0.2], 
         benchmark = ["USDT"], #SPY is set by default
         rebalance = "1y"
)
empyrial(portfolio)
# Out:
# 2 Failed downloads:
# - ETH: No data found, symbol may be delisted
# - BTC: Data doesn't exist for startDate = 1528491600, endDate = 1560027600
#
# 2 Failed downloads:
# - BTC: Data doesn't exist for startDate = 1560027600, endDate = 1591563600
# - ETH: No data found, symbol may be delisted
#
# 1 Failed download:
# - ETH: No data found, symbol may be delisted
#
# 1 Failed download:
# - ETH: No data found, symbol may be delisted
#
# 1 Failed download:
# - ETH: No data found, symbol may be delisted
# Start date: 2018-06-09
# End date: 2022-07-21
#
# 1 Failed download:
# - USDT: No data found, symbol may be delisted
#                      Backtest
#
# Annual return           1.53%
# Cumulative return       6.43%
# Annual volatility      7.09 %
# Winning day ratio      51.98%
# Sharpe ratio             0.25
# Calmar ratio             0.13
# Information ratio         NaN
# Stability                0.17
# Max Drawdown         -12.04 %
# Sortino ratio            0.34
# ...
